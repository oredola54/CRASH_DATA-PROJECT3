# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
crash_data=pd.read_excel("C:/Users/kola pc/Desktop/Crash Data.xlsx")
crash_data
# Out:
#        Crash ID State  Month  Year    Dayweek      Time Crash Type  \
# 0      20212133   Vic      9  2021     Sunday  00:30:00     Single
# 1      20214022    SA      9  2021   Saturday  23:31:00   Multiple
# 2      20212096   Vic      9  2021   Saturday  23:00:00     Single
# 3      20212145   Vic      9  2021   Saturday  22:25:00     Single
# 4      20212075   Vic      9  2021   Saturday  05:15:00     Single
# ...         ...   ...    ...   ...        ...       ...        ...
# 52838  19891246   NSW      1  1989  Wednesday  17:05:00     Single
# 52839  19895088    WA      1  1989     Monday  06:00:00     Single
# 52840  19895088    WA      1  1989     Monday  06:00:00     Single
# 52841  19895088    WA      1  1989     Monday  06:00:00     Single
# 52842  19896063   Tas      1  1989    Tuesday  12:40:00   Multiple
#
#       Bus Involvement Heavy Rigid Truck Involvement  \
# 0                 NaN                           NaN
# 1                  No                            No
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4                 NaN                           NaN
# ...               ...                           ...
# 52838             Yes                           NaN
# 52839              No                           NaN
# 52840              No                           NaN
# 52841              No                           NaN
# 52842              No                           NaN
#
#       Articulated Truck Involvement  ... Age  National Remoteness Areas  \
# 0                               NaN  ...  38   Inner Regional Australia
# 1                                No  ...  28  Major Cities of Australia
# 2                               NaN  ...  19   Inner Regional Australia
# 3                               NaN  ...  23   Outer Regional Australia
# 4                               NaN  ...  46  Major Cities of Australia
# ...                             ...  ...  ..                        ...
# 52838                            No  ...   5                        NaN
# 52839                            No  ...  19                        NaN
# 52840                            No  ...  17                        NaN
# 52841                            No  ...  17                        NaN
# 52842                            No  ...  63                        NaN
#
#                 SA4 Name 2016  National LGA Name 2017 National Road Type  \
# 0      Melbourne - Outer East        Yarra Ranges (S)      Arterial Road
# 1            Adelaide - North            Playford (C)                NaN
# 2                        Hume         Wangaratta (RC)        Access road
# 3                        Hume         Wangaratta (RC)      Arterial Road
# 4      Melbourne - South East               Casey (C)         Local Road
# ...                       ...                     ...                ...
# 52838                     NaN                     NaN                NaN
# 52839                     NaN                     NaN                NaN
# 52840                     NaN                     NaN                NaN
# 52841                     NaN                     NaN                NaN
# 52842                     NaN                     NaN                NaN
#
#       Christmas Period Easter Period Age Group Day of week Time of day
# 0                   No            No  26_to_39     Weekend       Night
# 1                   No            No  26_to_39     Weekend       Night
# 2                   No            No  17_to_25     Weekend       Night
# 3                   No            No  17_to_25     Weekend       Night
# 4                   No            No  40_to_64     Weekend       Night
# ...                ...           ...       ...         ...         ...
# 52838               No            No   0_to_16     Weekday         Day
# 52839              Yes            No  17_to_25     Weekday         Day
# 52840              Yes            No  17_to_25     Weekday         Day
# 52841              Yes            No  17_to_25     Weekday         Day
# 52842               No            No  40_to_64     Weekday         Day
#
# [52843 rows x 23 columns]

# %%
crash_data.columns
# Out:
# Index(['Crash ID', 'State', 'Month', 'Year', 'Dayweek', 'Time', 'Crash Type',
#        'Bus Involvement', 'Heavy Rigid Truck Involvement',
#        'Articulated Truck Involvement', 'Speed Limit', 'Road User', 'Gender',
#        'Age', 'National Remoteness Areas', 'SA4 Name 2016',
#        'National LGA Name 2017', 'National Road Type', 'Christmas Period',
#        'Easter Period', 'Age Group', 'Day of week', 'Time of day'],
#       dtype='object')

# %%
Accident=crash_data.groupby("Dayweek")["Dayweek"].count()
Accident
# Out:
# Dayweek
# Friday       8665
# Monday       6108
# Saturday     9696
# Sunday       8460
# Thursday     7106
# Tuesday      6145
# Wednesday    6663
# Name: Dayweek, dtype: int64

# %%
name=Accident.index
number=Accident.values

# %%
crash_data["Speed Limit"]=crash_data["Speed Limit"].fillna(0)

# %%
crash_data["Speed Limit"]=crash_data["Speed Limit"].replace({"Unspecified":0,"<40":40}).astype(int)

# %%
speed=crash_data.groupby("Road User")["Speed Limit"].mean()
speed
# Out:
# Road User
# Driver                          86.404854
# Motorcycle pillion passenger    74.977961
# Motorcycle rider                75.685400
# Other/-9                        60.782609
# Passenger                       84.062026
# Pedal cyclist                   70.808989
# Pedestrian                      65.869207
# Name: Speed Limit, dtype: float64

# %%
name0=speed.index
number0=speed.values

# %%
total_Accident_user=crash_data.groupby("Road User")["Road User"].count()
total_Accident_user
# Out:
# Road User
# Driver                          23816
# Motorcycle pillion passenger      363
# Motorcycle rider                 6637
# Other/-9                           92
# Passenger                       12269
# Pedal cyclist                    1424
# Pedestrian                       8242
# Name: Road User, dtype: int64

# %%
name1=total_Accident_user
number1=total_Accident_user

# %%
total_accident_gender=crash_data.groupby("Gender")["Gender"].count()
total_accident_gender
# Out:
# Gender
# Female         15002
# Male           37813
# Unspecified        1
# Name: Gender, dtype: int64

# %%
name2=total_accident_gender.index
number2=total_accident_gender.values

# %%
total_Accident_user=crash_data.groupby("Road User")["Road User"].count()
total_Accident_user
# Out:
# Road User
# Driver                          23816
# Motorcycle pillion passenger      363
# Motorcycle rider                 6637
# Other/-9                           92
# Passenger                       12269
# Pedal cyclist                    1424
# Pedestrian                       8242
# Name: Road User, dtype: int64

# %%
name2=total_Accident_user
number2=total_Accident_user

# %%
Roadage=crash_data.groupby("Road User")["Age"].mean()
Roadage
# Out:
# Road User
# Driver                          41.397674
# Motorcycle pillion passenger    28.311295
# Motorcycle rider                35.017026
# Other/-9                        36.434783
# Passenger                       34.481213
# Pedal cyclist                   38.610955
# Pedestrian                      46.819097
# Name: Age, dtype: float64

# %%
name3=Roadage.index
number3=Roadage.values

# %%
accident_days_week=crash_data.groupby("Day of week")["Day of week"].count()
accident_days_week
# Out:
# Day of week
# Weekday    31066
# Weekend    21777
# Name: Day of week, dtype: int64

# %%
name4=accident_days_week.index
number4=accident_days_week.values

# %%
fig,crash_data=plt.subplots(nrows=2,ncols=3,figsize=(14,8))
fig.suptitle("Crash_Data",fontsize=20,fontstyle="italic",fontweight="bold",c="r")
crash_data[0,0].barh(name,number)
crash_data[0,1].bar(name0,number0)
crash_data[0,2].plot(name1,number1)
crash_data[1,0].pie(number2,labels=name2,autopct="%1.0f%%",shadow=True,explode=[0,0.1,0])
crash_data[1,1].scatter(name3,number3)
crash_data[1,2].bar(name4,number4)
crash_data[0,0].set(title="Accident for each the day")
crash_data[0,1].set(title="Average speed")
crash_data[0,2].set(title="Accident for each road user")
crash_data[1,0].set(title="Accident for gender")
crash_data[1,1].set(title="Average age for each raod user")
crash_data[1,2].set(title="Accident for each day of the week")
plt.tight_layout()
plt.savefig("Crash_Data.png")
plt.show()
